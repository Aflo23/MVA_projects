# %%
import numpy as np
import torch
import random

# %%
import torch

# %% [markdown]
# ### Task 4 & Result of PART I

# %%
# %run part1/gnn_karate.py
# Out:
# Number of nodes: 34
# Number of edges: 78
# /Users/antoine/Downloads/ALTEGRAD_lab_6_DLForGraphs_2024/code/part1/models.py:43: UserWarning: torch.sparse.SparseTensor(indices, values, shape, *, device=) is deprecated.  Please use torch.sparse_coo_tensor(indices, values, shape, dtype=, device=). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:620.)
#   adj_att = torch.sparse.FloatTensor(indices, alpha, torch.Size([x.size(0), x.size(0)])).to(x.device)
# Epoch: 001 loss_train: 0.7045 acc_train: 0.4444 time: 0.0603s
# Epoch: 002 loss_train: 0.6946 acc_train: 0.4444 time: 0.0046s
# Epoch: 003 loss_train: 0.6872 acc_train: 0.4815 time: 0.0041s
# Epoch: 004 loss_train: 0.6800 acc_train: 0.8889 time: 0.0035s
# Epoch: 005 loss_train: 0.6601 acc_train: 1.0000 time: 0.0043s
# Epoch: 006 loss_train: 0.6444 acc_train: 1.0000 time: 0.0044s
# Epoch: 007 loss_train: 0.6206 acc_train: 1.0000 time: 0.0053s
# ...

# %% [markdown]
# Part uniform nodes

# %%
# %run part1/gnn_karate.py
# Out:
# Number of nodes: 34
# Number of edges: 78
# /Users/antoine/Downloads/ALTEGRAD_lab_6_DLForGraphs_2024/code/part1/models.py:43: UserWarning: torch.sparse.SparseTensor(indices, values, shape, *, device=) is deprecated.  Please use torch.sparse_coo_tensor(indices, values, shape, dtype=, device=). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:620.)
#   adj_att = torch.sparse.FloatTensor(indices, alpha, torch.Size([x.size(0), x.size(0)])).to(x.device)
# Epoch: 001 loss_train: 0.7214 acc_train: 0.4444 time: 0.0355s
# Epoch: 002 loss_train: 0.7141 acc_train: 0.4444 time: 0.0057s
# Epoch: 003 loss_train: 0.7016 acc_train: 0.4444 time: 0.0045s
# Epoch: 004 loss_train: 0.6881 acc_train: 0.7037 time: 0.0045s
# Epoch: 005 loss_train: 0.6875 acc_train: 0.5556 time: 0.0042s
# Epoch: 006 loss_train: 0.6811 acc_train: 0.5556 time: 0.0044s
# Epoch: 007 loss_train: 0.6769 acc_train: 0.5556 time: 0.0038s
# ...

# %%
# run part 2 gnn
# %run part2/gnn.py
# Out:
# first time hello
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/Downloads/ALTEGRAD_lab_6_DLForGraphs_2024/code/part2/gnn.py:100
#      97 ##################
#      99 optimizer.zero_grad()
# --> 100 output = model(features_batch, adj_batch, idx_batch)
#     101 loss = loss_function(output, y_batch)
#     102 train_loss += loss.item() * output.size(0)
#
# File ~/anaconda3/envs/altegrad-lab4/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/altegrad-lab4/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
# ...

# %%
from tp_template.autoreload import autoreload_if_notebook

autoreload_if_notebook()
# Out:
# Autoreload activated

# %%
# %run part2/gnn.py
# Out:
# hello
# first time hello
# /Users/antoine/Downloads/ALTEGRAD_lab_6_DLForGraphs_2024/code/part2/utils.py:47: UserWarning: torch.sparse.SparseTensor(indices, values, shape, *, device=) is deprecated.  Please use torch.sparse_coo_tensor(indices, values, shape, dtype=, device=). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:620.)
#   return torch.sparse.FloatTensor(indices, values, shape)
# Epoch: 0001 loss_train: 117.2622 acc_train: 0.4778 time: 0.4052s
# Epoch: 0011 loss_train: 0.6964 acc_train: 0.5000 time: 0.1230s
# Epoch: 0021 loss_train: 0.6955 acc_train: 0.5000 time: 0.0881s
# Epoch: 0031 loss_train: 0.6955 acc_train: 0.5000 time: 0.0907s
# Epoch: 0041 loss_train: 0.6955 acc_train: 0.5000 time: 0.1050s
# Epoch: 0051 loss_train: 0.6955 acc_train: 0.5000 time: 0.0897s
# Epoch: 0061 loss_train: 0.6955 acc_train: 0.5000 time: 0.0984s
# Epoch: 0071 loss_train: 0.6955 acc_train: 0.5000 time: 0.0981s
# ...

# %%
# %run part2/gnn.py
# Out:
# first time hello
# /Users/antoine/Downloads/ALTEGRAD_lab_6_DLForGraphs_2024/code/part2/utils.py:42: UserWarning: torch.sparse.SparseTensor(indices, values, shape, *, device=) is deprecated.  Please use torch.sparse_coo_tensor(indices, values, shape, dtype=, device=). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:620.)
#   return torch.sparse.FloatTensor(indices, values, shape)
# Epoch: 0001 loss_train: 11.7933 acc_train: 0.4333 time: 0.2696s
# Epoch: 0011 loss_train: 0.3202 acc_train: 0.8667 time: 0.0786s
# Epoch: 0021 loss_train: 0.3371 acc_train: 0.8778 time: 0.0728s
# Epoch: 0031 loss_train: 0.3119 acc_train: 0.8889 time: 0.0773s
# Epoch: 0041 loss_train: 0.2908 acc_train: 0.8778 time: 0.0770s
# Epoch: 0051 loss_train: 0.3042 acc_train: 0.8889 time: 0.0776s
# Epoch: 0061 loss_train: 0.3129 acc_train: 0.8222 time: 0.0794s
# Epoch: 0071 loss_train: 0.2506 acc_train: 0.8778 time: 0.0774s
# ...

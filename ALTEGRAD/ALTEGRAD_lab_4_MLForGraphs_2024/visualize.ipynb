# %%
import numpy as np

# %%
# %run code/part1/code_lab_exploration.py
# Out:
# Number of nodes: 9877
# Number of edges: 25998
# Number of connected components: 429
# Largest connected component has 8638 nodes and 24827 edges
# Fraction of nodes in the largest connected component: 0.8746
# Fraction of edges in the largest connected component: 0.9550

# %% [markdown]
# ### Task

# %%
# %run code/part2/code_lab_community_detection.py
# Out:
# Number of nodes in GCC: 8638
# Number of edges in GCC: 24827
# ...

# %% [markdown]
# So modularity are not very high actually.

# %% [markdown]
# ### Tasks 8 to 9

# %%
import torch_geometric

# %%
# %run code/part3/code_lab_graph_classification.py
# Out:
# ...
# Processing...
# Done!
# /Users/antoine/Downloads/ALTEGRAD_lab_4_MLForGraphs_2024/code/part3/code_lab_graph_classification.py:127: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   K_train_sp, K_test_sp = shortest_path_kernel(G_train, G_test)
# /Users/antoine/Downloads/ALTEGRAD_lab_4_MLForGraphs_2024/code/part3/code_lab_graph_classification.py:148: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
# Accuracy of SVM with Shortest Path Kernel: 0.8947368421052632
# Accuracy of SVM with Graphlet Kernel: 0.8157894736842105

# %% [markdown]
# ### Results:
#
#
# - Accuracy of SVM with Shortest Path Kernel: 0.8947368421052632
# - Accuracy of SVM with Graphlet Kernel: 0.8157894736842105

# %% [markdown]
# ### Task 11 to 14

# %%
# %run code/part3/grakel.py
# Out:
# Vocabulary size:  7151
# Example of graph-of-words representation of document
# Accuracy: 0.938
# Accuracy with Shortest Path Kernel: 0.966

# %% [markdown]
# ##

# %% [markdown]
# ## Conclusion
#
# The performances here on that type of SVM are significantly interesting.

# %%
 6/13 - (13/26)**2 + 6/13 - (13/26)**2
# Out:
# 0.42307692307692313

# %%
2/13 - (11/26)**2 + 4/13 - (15/26)**2
# Out:
# -0.05029585798816555
